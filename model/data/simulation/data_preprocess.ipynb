#
# [6000 rows x 1001 columns]

# %%
num_data = data.shape[0]
np.random.seed(3407)
_new_order = list(range(num_data))
np.random.shuffle(_new_order)
data = data[_new_order, :]
data_df = pd.DataFrame(data)
data_df
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.018488  0.019898  0.022089  0.022357  0.021117  0.021765  0.023006
# 1     0.001081  0.001628  0.002917  0.002243  0.000022 -0.000356 -0.000184
# 2     0.000100  0.000593  0.001824  0.001091 -0.001194 -0.001635 -0.001532
# 3     0.001898  0.002644  0.004153  0.003726  0.001779  0.001703  0.002213
# 4     0.005726  0.007007  0.009116  0.009357  0.008158  0.008924  0.010364
# ...        ...       ...       ...       ...       ...       ...       ...
# 5995  0.010055  0.011148  0.013014  0.012949  0.011369  0.011669  0.012553
# 5996  0.006582  0.007764  0.009742  0.009824  0.008428  0.008946  0.010103
# 5997  0.001038  0.001574  0.002850  0.002164 -0.000072 -0.000464 -0.000306
# 5998  0.017603  0.019046  0.021277  0.021592  0.020406  0.021116  0.022426
# 5999  0.004181  0.005259  0.007142  0.007132  0.005655  0.006103  0.007200
#
#           7         8         9     ...      991       992       993   \
# 0     0.022869  0.024378  0.026000  ...  0.235975  0.228303  0.219452
# 1    -0.001441 -0.001106 -0.000707  ...  0.020450  0.019067  0.016370
# 2    -0.002861 -0.002602 -0.002282  ...  0.020978  0.019285  0.016319
# 3     0.001326  0.002070  0.002919  ...  0.019792  0.019097  0.017031
# 4     0.010511  0.012416  0.014548  ...  0.156032  0.153610  0.149819
# ...        ...       ...       ...  ...       ...       ...       ...
# 5995  0.012046  0.013171  0.014401  ...  0.196953  0.190766  0.183356
# 5996  0.009909  0.011404  0.013064  ...  0.129313  0.126493  0.122337
# 5997 -0.001582 -0.001263 -0.000884  ...  0.026220  0.024376  0.021261
# 5998  0.022362  0.023947  0.025654  ...  0.147130  0.142291  0.136198
# 5999  0.006968  0.008437  0.010101  ...  0.157162  0.154464  0.150440
#
#           994       995       996       997       998       999   1000
# 0     0.210674  0.203583  0.195897  0.188409  0.180963  0.175769   1.0
# 1     0.013603  0.012383  0.010446  0.008575  0.006627  0.006798   0.0
# 2     0.013313  0.011895  0.009785  0.007772  0.005699  0.005773   0.0
# 3     0.014838  0.014139  0.012667  0.011224  0.009651  0.010160   0.0
# 4     0.145927  0.143533  0.140402  0.137290  0.134090  0.132967   1.0
# ...        ...       ...       ...       ...       ...       ...   ...
# 5995  0.175957  0.170197  0.163803  0.157567  0.151336  0.147319   1.0
# 5996  0.118098  0.115381  0.111920  0.108536  0.105046  0.103666   1.0
# 5997  0.018094  0.016515  0.014236  0.012053  0.009812  0.009714   0.0
# 5998  0.130088  0.125590  0.120428  0.115398  0.110345  0.107480   1.0
# 5999  0.146292  0.143672  0.140301  0.136971  0.133549  0.132214   1.0
#
# [6000 rows x 1001 columns]

# %%
class_0_data_df = data_df[data_df.iloc[:, -1] == 0]
class_1_data_df = data_df[data_df.iloc[:, -1] == 1]

# %%
print(f"In total we have {num_data} examples")
test_n = 4000
# Out:
# In total we have 6000 examples

# %% [markdown]
# # True data

# %%
data_true = pd.read_csv("row_data/allTrueSignals.csv", header=None)
# delete NaNs
clean_data_true = data_true.dropna()
new_column_data = [0.] * 3000 + [1.] * 3000
# 添加新列
clean_data_true['1000'] = new_column_data
data_true = clean_data_true.values
data_true = data_true[_new_order, :]
data_true_df = pd.DataFrame(data_true)
data_true_df
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.019604  0.020746  0.021949  0.023216  0.024550  0.025954  0.027431
# 1     0.002197  0.002355  0.002524  0.002703  0.002895  0.003100  0.003318
# 2     0.001216  0.001310  0.001410  0.001518  0.001633  0.001757  0.001890
# 3     0.003014  0.003223  0.003446  0.003683  0.003936  0.004204  0.004490
# 4     0.006842  0.007315  0.007818  0.008353  0.008922  0.009527  0.010170
# ...        ...       ...       ...       ...       ...       ...       ...
# 5995  0.011171  0.011890  0.012652  0.013460  0.014315  0.015220  0.016178
# 5996  0.007698  0.008211  0.008756  0.009335  0.009949  0.010600  0.011291
# 5997  0.002154  0.002308  0.002473  0.002650  0.002838  0.003038  0.003252
# 5998  0.018718  0.019809  0.020957  0.022167  0.023441  0.024781  0.026192
# 5999  0.005297  0.005676  0.006080  0.006512  0.006972  0.007462  0.007984
#
#           7         8         9     ...      991       992       993   \
# 0     0.028985  0.030619  0.032338  ...  0.225366  0.219128  0.213043
# 1     0.003550  0.003798  0.004062  ...  0.015638  0.014903  0.014201
# 2     0.002032  0.002184  0.002347  ...  0.014272  0.013585  0.012928
# 3     0.004794  0.005117  0.005461  ...  0.020395  0.019461  0.018568
# 4     0.010853  0.011579  0.012349  ...  0.172416  0.167551  0.162808
# ...        ...       ...       ...  ...       ...       ...       ...
# 5995  0.017191  0.018263  0.019396  ...  0.190510  0.185135  0.179893
# 5996  0.012023  0.012799  0.013621  ...  0.138116  0.133899  0.129797
# 5997  0.003480  0.003722  0.003981  ...  0.019743  0.018839  0.017974
# 5998  0.027675  0.029236  0.030877  ...  0.142299  0.138040  0.133895
# 5999  0.008540  0.009132  0.009762  ...  0.172259  0.167303  0.162474
#
#           994       995       996       997       998       999   1000
# 0     0.207107  0.201317  0.195671  0.190165  0.184797  0.179563   1.0
# 1     0.013530  0.012888  0.012274  0.011688  0.011127  0.010592   0.0
# 2     0.012301  0.011702  0.011130  0.010584  0.010064  0.009567   0.0
# 3     0.017712  0.016893  0.016108  0.015358  0.014640  0.013954   0.0
# 4     0.158183  0.153676  0.149282  0.145000  0.140827  0.136761   1.0
# ...        ...       ...       ...       ...       ...       ...   ...
# 5995  0.174784  0.169803  0.164948  0.160216  0.155606  0.151113   1.0
# 5996  0.125808  0.121929  0.118157  0.114490  0.110925  0.107460   1.0
# 5997  0.017146  0.016353  0.015594  0.014867  0.014172  0.013508   0.0
# 5998  0.129862  0.125937  0.122118  0.118403  0.114789  0.111274   1.0
# 5999  0.157768  0.153184  0.148718  0.144369  0.140133  0.136008   1.0
#
# [6000 rows x 1001 columns]

# %%
class_0_true_data_df = data_true_df[data_true_df.iloc[:, -1] == 0]
class_1_true_data_df = data_true_df[data_true_df.iloc[:, -1] == 1]

# %%
# keep test/valid

# train/valid
split = (4, 1) 
num_tr_val = num_data - test_n
train_n = num_tr_val // sum(split) * split[0]
valid_n = num_tr_val // sum(split) * split[1]

class_0_true_data_df = class_0_true_data_df.values
class_1_true_data_df = class_1_true_data_df.values

# for test and valid, randomly choose test/2 and valid_n/2 from each class to build a balance test/valid set (the rest examples are left for the train set)
n_test_class_0_split = test_n // 2
n_test_class_1_split = test_n - n_test_class_0_split

n_valid_class_0_split = valid_n // 2
n_valid_class_1_split = valid_n - n_valid_class_0_split

raw_data_true_test_0 = pd.DataFrame(class_0_true_data_df[:n_test_class_0_split, :])
raw_data_true_valid_0 = pd.DataFrame(class_0_true_data_df[n_test_class_0_split:(n_test_class_0_split+n_valid_class_0_split), :])
raw_data_true_train_0 = pd.DataFrame(class_0_true_data_df[(n_test_class_0_split+n_valid_class_0_split):, :])

raw_data_true_test_1 = pd.DataFrame(class_1_true_data_df[:n_test_class_1_split, :])
raw_data_true_valid_1 = pd.DataFrame(class_1_true_data_df[n_test_class_1_split:(n_test_class_1_split+n_valid_class_1_split), :])
raw_data_true_train_1 = pd.DataFrame(class_1_true_data_df[(n_test_class_1_split+n_valid_class_1_split):, :])

# merge
raw_data_true_train = pd.concat([raw_data_true_train_0, raw_data_true_train_1])
raw_data_true_valid = pd.concat([raw_data_true_valid_0, raw_data_true_valid_1])
raw_data_true_test = pd.concat([raw_data_true_test_0, raw_data_true_test_1])

len(raw_data_true_train), len(raw_data_true_valid), len(raw_data_true_test)
# Out:
# (1600, 400, 4000)

# %%
d_len = data_true_df.shape[1] - 1 # last col
raw_data_true_train[d_len] = raw_data_true_train[d_len].astype(int)
raw_data_true_valid[d_len] = raw_data_true_valid[d_len].astype(int)
raw_data_true_test[d_len] = raw_data_true_test[d_len].astype(int)

# %%
case = 'medium'
fo_dir = case + "/"
raw_data_true_train.to_csv(fo_dir + 'train_true.csv', index=False, header=False)
raw_data_true_valid.to_csv(fo_dir + 'valid_true.csv', index=False, header=False)
raw_data_true_test.to_csv(fo_dir + 'test_true.csv', index=False, header=False)

# %% [markdown]
# # Split

# %%
# keep test/valid

# train/valid
split = (4, 1) 
num_tr_val = num_data - test_n
train_n = num_tr_val // sum(split) * split[0]
valid_n = num_tr_val // sum(split) * split[1]

class_0_data_df = class_0_data_df.values
class_1_data_df = class_1_data_df.values

# for test and valid, randomly choose test/2 and valid_n/2 from each class to build a balance test/valid set (the rest examples are left for the train set)
n_test_class_0_split = test_n // 2
n_test_class_1_split = test_n - n_test_class_0_split

n_valid_class_0_split = valid_n // 2
n_valid_class_1_split = valid_n - n_valid_class_0_split

raw_data_test_0 = pd.DataFrame(class_0_data_df[:n_test_class_0_split, :])
raw_data_valid_0 = pd.DataFrame(class_0_data_df[n_test_class_0_split:(n_test_class_0_split+n_valid_class_0_split), :])
raw_data_train_0 = pd.DataFrame(class_0_data_df[(n_test_class_0_split+n_valid_class_0_split):, :])

raw_data_test_1 = pd.DataFrame(class_1_data_df[:n_test_class_1_split, :])
raw_data_valid_1 = pd.DataFrame(class_1_data_df[n_test_class_1_split:(n_test_class_1_split+n_valid_class_1_split), :])
raw_data_train_1 = pd.DataFrame(class_1_data_df[(n_test_class_1_split+n_valid_class_1_split):, :])

# merge
raw_data_train = pd.concat([raw_data_train_0, raw_data_train_1])
raw_data_valid = pd.concat([raw_data_valid_0, raw_data_valid_1])
raw_data_test = pd.concat([raw_data_test_0, raw_data_test_1])

len(raw_data_train), len(raw_data_valid), len(raw_data_test)
# Out:
# (1600, 400, 4000)

# %%
train_n, valid_n, test_n
# Out:
# (1600, 400, 4000)

# %%
d_len = data_df.shape[1] - 1 # last col
d_len
# Out:
# 1000

# %%
raw_data_train[d_len] = raw_data_train[d_len].astype(int)
raw_data_valid[d_len] = raw_data_valid[d_len].astype(int)
raw_data_test[d_len] = raw_data_test[d_len].astype(int)

# %%
counts = raw_data_train[raw_data_train.columns[-1]].value_counts()
counts
# Out:
# 0    800
# 1    800
# Name: 1000, dtype: int64

# %%
counts = raw_data_valid[raw_data_valid.columns[-1]].value_counts()
counts
# Out:
# 0    200
# 1    200
# Name: 1000, dtype: int64

# %%
counts = raw_data_test[raw_data_test.columns[-1]].value_counts()
counts
# Out:
# 0    2000
# 1    2000
# Name: 1000, dtype: int64

# %% [markdown]
# save train/valid/test data and use them for all control experiments

# %%
print(f"train_n = {len(raw_data_train)}\nvalid_n = {len(raw_data_valid)}\ntest_n = {len(raw_data_test)}")
# Out:
# train_n = 1600
# valid_n = 400
# test_n = 4000

# %%
# save to csv
fo_dir = case + "/"
raw_data_train.to_csv(fo_dir + 'train.csv', index=False, header=False)
raw_data_valid.to_csv(fo_dir + 'valid.csv', index=False, header=False)
raw_data_test.to_csv(fo_dir + 'test.csv', index=False, header=False)
